# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Tout est prêt")
# Out:
# Tout est prêt

# %% [markdown]
# # Pourquoi un Data Analyst est payé?
# Parce qu'il transforme des données brutes en décisions business claires.
